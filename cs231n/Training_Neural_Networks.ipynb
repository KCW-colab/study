# %%
import numpy as np
import matplotlib.pyplot as plt


# assume some unit gaussian 10-D input data

D = np.random.randn(1000, 500)
hidden_layer_sizes = [500] * 10
nonlinearities = ['tanh'] * len(hidden_layer_sizes)

# %%
act = {'relu' : lambda x: np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
  X = D if i == 0 else Hs[i-1] # input at this layer
  fan_in = X.shape[1]
  fan_out = hidden_layer_sizes[i]
  W = np.random.randn(fan_in, fan_out) * 0.01 # layer initialization

  H = np.dot(X, W) # matrix multiply
  H = act[nonlinearities[i]](H) # nonlinearity
  Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print("input layer had mean %f and std %f"%(np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
  print("hidden layer %d had mean %f and std %f"%(i+1, layer_means[i], layer_stds[i]))

# plot the means and standard deviations

plt.figure(figsize=(12,8))
plt.subplot(121)
plt.plot(list(Hs.keys()), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(list(Hs.keys()), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure(figsize=(12,8))
for i, H in Hs.items():
  plt.subplot(1, len(Hs), i+1)
  plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean 0.001649 and std 1.001816
# hidden layer 1 had mean -0.000213 and std 0.214456
# hidden layer 2 had mean -0.000081 and std 0.047724
# hidden layer 3 had mean 0.000015 and std 0.010665
# hidden layer 4 had mean -0.000007 and std 0.002381
# hidden layer 5 had mean -0.000002 and std 0.000530
# hidden layer 6 had mean -0.000000 and std 0.000119
# hidden layer 7 had mean 0.000000 and std 0.000027
# hidden layer 8 had mean -0.000000 and std 0.000006
# hidden layer 9 had mean -0.000000 and std 0.000001
# hidden layer 10 had mean 0.000000 and std 0.000000

# %% [markdown]
# **If weight is Big**

# %%
act = {'relu' : lambda x: np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
  X = D if i == 0 else Hs[i-1] # input at this layer
  fan_in = X.shape[1]
  fan_out = hidden_layer_sizes[i]
  W = np.random.randn(fan_in, fan_out) * 1 # layer initialization

  H = np.dot(X, W) # matrix multiply
  H = act[nonlinearities[i]](H) # nonlinearity
  Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print("input layer had mean %f and std %f"%(np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
  print("hidden layer %d had mean %f and std %f"%(i+1, layer_means[i], layer_stds[i]))

# plot the means and standard deviations

plt.figure(figsize=(12,8))
plt.subplot(121)
plt.plot(list(Hs.keys()), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(list(Hs.keys()), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure(figsize=(12,8))
for i, H in Hs.items():
  plt.subplot(1, len(Hs), i+1)
  plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean 0.001649 and std 1.001816
# hidden layer 1 had mean -0.003473 and std 0.981930
# hidden layer 2 had mean -0.001109 and std 0.981619
# hidden layer 3 had mean 0.000593 and std 0.981765
# hidden layer 4 had mean 0.000343 and std 0.981724
# hidden layer 5 had mean 0.000407 and std 0.981833
# hidden layer 6 had mean -0.001570 and std 0.981454
# hidden layer 7 had mean -0.001690 and std 0.981437
# hidden layer 8 had mean 0.000944 and std 0.981899
# hidden layer 9 had mean 0.001035 and std 0.981580
# hidden layer 10 had mean -0.001388 and std 0.981633

# %% [markdown]
# **Xavier initialization**

# %%
act = {'relu' : lambda x: np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
  X = D if i == 0 else Hs[i-1] # input at this layer
  fan_in = X.shape[1]
  fan_out = hidden_layer_sizes[i]
  W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in) # layer initialization
  
  H = np.dot(X, W) # matrix multiply
  H = act[nonlinearities[i]](H) # nonlinearity
  Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print("input layer had mean %f and std %f"%(np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
  print("hidden layer %d had mean %f and std %f"%(i+1, layer_means[i], layer_stds[i]))

# plot the means and standard deviations

plt.figure(figsize=(12,8))
plt.subplot(121)
plt.plot(list(Hs.keys()), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(list(Hs.keys()), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure(figsize=(12,8))
for i, H in Hs.items():
  plt.subplot(1, len(Hs), i+1)
  plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean 0.001649 and std 1.001816
# hidden layer 1 had mean -0.000171 and std 0.628638
# hidden layer 2 had mean 0.000044 and std 0.485463
# hidden layer 3 had mean -0.000426 and std 0.407778
# hidden layer 4 had mean -0.000042 and std 0.357374
# hidden layer 5 had mean -0.000522 and std 0.321481
# hidden layer 6 had mean -0.000122 and std 0.294278
# hidden layer 7 had mean 0.000341 and std 0.272479
# hidden layer 8 had mean 0.000625 and std 0.255175
# hidden layer 9 had mean 0.000122 and std 0.240275
# hidden layer 10 had mean -0.000315 and std 0.227494

# %% [markdown]
# **When we setting activation function as RELU**

# %%
act = {'relu' : lambda x: np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
nonlinearities2 = ['relu'] * len(hidden_layer_sizes)
for i in range(len(hidden_layer_sizes)):
  X = D if i == 0 else Hs[i-1] # input at this layer
  fan_in = X.shape[1]
  fan_out = hidden_layer_sizes[i]
  W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in) # layer initialization
  
  H = np.dot(X, W) # matrix multiply
  H = act[nonlinearities2[i]](H) # nonlinearity
  Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print("input layer had mean %f and std %f"%(np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
  print("hidden layer %d had mean %f and std %f"%(i+1, layer_means[i], layer_stds[i]))

# plot the means and standard deviations

plt.figure(figsize=(12,8))
plt.subplot(121)
plt.plot(list(Hs.keys()), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(list(Hs.keys()), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure(figsize=(12,8))
for i, H in Hs.items():
  plt.subplot(1, len(Hs), i+1)
  plt.hist(H.ravel(), 30, range=(0,1))
# Out:
# input layer had mean 0.001649 and std 1.001816
# hidden layer 1 had mean 0.397750 and std 0.583281
# hidden layer 2 had mean 0.270649 and std 0.403967
# hidden layer 3 had mean 0.187093 and std 0.277978
# hidden layer 4 had mean 0.138430 and std 0.198179
# hidden layer 5 had mean 0.091330 and std 0.137284
# hidden layer 6 had mean 0.060310 and std 0.087196
# hidden layer 7 had mean 0.046627 and std 0.063599
# hidden layer 8 had mean 0.030076 and std 0.044379
# hidden layer 9 had mean 0.022458 and std 0.031789
# hidden layer 10 had mean 0.014384 and std 0.022314

# %% [markdown]
# **He initialization**

# %%
act = {'relu' : lambda x: np.maximum(0, x), 'tanh': lambda x:np.tanh(x)}
Hs = {}
nonlinearities2 = ['relu'] * len(hidden_layer_sizes)
for i in range(len(hidden_layer_sizes)):
  X = D if i == 0 else Hs[i-1] # input at this layer
  fan_in = X.shape[1]
  fan_out = hidden_layer_sizes[i]
  W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2) # layer initialization
  
  H = np.dot(X, W) # matrix multiply
  H = act[nonlinearities2[i]](H) # nonlinearity
  Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print("input layer had mean %f and std %f"%(np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i, H in Hs.items()]
layer_stds = [np.std(H) for i, H in Hs.items()]
for i, H in Hs.items():
  print("hidden layer %d had mean %f and std %f"%(i+1, layer_means[i], layer_stds[i]))

# plot the means and standard deviations

plt.figure(figsize=(12,8))
plt.subplot(121)
plt.plot(list(Hs.keys()), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(list(Hs.keys()), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure(figsize=(12,8))
for i, H in Hs.items():
  plt.subplot(1, len(Hs), i+1)
  plt.hist(H.ravel(), 30, range=(0,1))
# Out:
# input layer had mean 0.001649 and std 1.001816
# hidden layer 1 had mean 0.563341 and std 0.827013
# hidden layer 2 had mean 0.546575 and std 0.820437
# hidden layer 3 had mean 0.591174 and std 0.863151
# hidden layer 4 had mean 0.632124 and std 0.868513
# hidden layer 5 had mean 0.534550 and std 0.828404
# hidden layer 6 had mean 0.527912 and std 0.788242
# hidden layer 7 had mean 0.434686 and std 0.679666
# hidden layer 8 had mean 0.441463 and std 0.653126
# hidden layer 9 had mean 0.464853 and std 0.665038
# hidden layer 10 had mean 0.434261 and std 0.642232
